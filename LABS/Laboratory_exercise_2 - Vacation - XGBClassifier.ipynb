# %% [markdown]
# # Requirements

# %%
# Add as many imports as you need.
import pandas as pd

# %% [markdown]
# # Laboratory Exercise - Run Mode (8 points)

# %% [markdown]
# ## The Vacation Preferences Dataset
# The dataset contains information about individuals and their vacation preferences. It includes details such as age, gender, income, and education level. It also provides insights into their vacation habits, like the number of vacations taken each year, preferred activities (such as hiking, swimming, skiing, or sunbathing), and their budget for vacations. Other information includes the type of place they live in (urban, suburban, or rural), how far they live from mountains and beaches, and their favorite season for vacations (summer, winter, spring, or fall). The dataset also contains information whether they have pets and if they are concerned about the environment. All these features serve as input variables for predictive modeling. The 'Preference' attribute serves as the target variable, where 1 represents preference for mountains, 0 for beaches.

# %% [markdown]
# Load the dataset into a `pandas` data frame.

# %%
# Write your code here. Add as many boxes as you need.
data = pd.read_csv('vacation_preferences_data.csv')

# %%
data.head()
# Out:
#     Age      Gender  Income Education_Level  Travel_Frequency  \
# 0  56.0        male   71477        bachelor                 9
# 1  69.0        male   88740          master                 1
# 2  46.0      female   46562          master                 0
# 3  32.0  non-binary   99044     high school                 6
# 4  60.0      female  106583     high school                 5
#
#   Preferred_Activities  Vacation_Budget  Location  Proximity_to_Mountains  \
# 0               skiing             2477     urban                   175.0
# 1             swimming             4777  suburban                     NaN
# 2               skiing             1469     urban                    71.0
# 3               hiking             1482     rural                    31.0
# 4           sunbathing              516  suburban                    23.0
#
#    Proximity_to_Beaches Favorite_Season  Pets  Environmental_Concerns  \
# 0                   267          summer     0                       1
# 1                   190            fall     0                       1
# 2                   280          winter     0                       0
# 3                   255          summer     1                       0
# 4                   151          winter     1                       1
#
#    Preference
# 0           1
# 1           0
# 2           1
# 3           1
# 4           0

# %% [markdown]
# Preprocess the input and the output variables appropriately.

# %%
# Write your code here. Add as many boxes as you need.

# %% [markdown]
# Explore the dataset using visualizations of your choice.

# %%
# Write your code here. Add as many boxes as you need.

# %% [markdown]
# Check if the dataset is balanced.

# %%
# Write your code here. Add as many boxes as you need.
data['Preference'].value_counts()
# Out:
# Preference
# 0    39296
# 1    13148
# Name: count, dtype: int64

# %% [markdown]
# ## Detecting Missing Values
# Calculate the percentage of missing values present in each column of the dataset.

# %%
# Write your code here. Add as many boxes as you need.
data.isnull().sum()
# Out:
# Age                       5244
# Gender                       0
# Income                       0
# Education_Level           2622
# Travel_Frequency             0
# Preferred_Activities         0
# Vacation_Budget              0
# Location                     0
# Proximity_to_Mountains    2622
# Proximity_to_Beaches         0
# Favorite_Season              0
# Pets                         0
# Environmental_Concerns       0
# Preference                   0
# dtype: int64

# %%
percent = data.isnull().sum() / len(data) * 100

# %%
percent
# Out:
# Age                       9.999237
# Gender                    0.000000
# Income                    0.000000
# Education_Level           4.999619
# Travel_Frequency          0.000000
# Preferred_Activities      0.000000
# Vacation_Budget           0.000000
# Location                  0.000000
# Proximity_to_Mountains    4.999619
# Proximity_to_Beaches      0.000000
# Favorite_Season           0.000000
# Pets                      0.000000
# Environmental_Concerns    0.000000
# Preference                0.000000
# dtype: float64

# %% [markdown]
# ## Understanding the Causes Behind Missing Values
# Using visualization tools such as heatmaps, and dendrograms, illustrate the interdependence between attributes with missing values. Also, visualize the distribution of the missing values within the dataset using matrices and bar charts.

# %%
# Write your code here. Add as many boxes as you need.
import missingno as msn

# %%
msn.heatmap(data)
# Out:
# <Axes: >

# %%
msn.dendrogram(data)
# Out:
# <Axes: >

# %% [markdown]
# ## Handling the Missing Values
# Handle the missing values using suitable method based on the insights obtained from the various visualizations.

# %%
# Write your code here. Add as many boxes as you need.
data.isnull().sum()
# Out:
# Age                       5244
# Gender                       0
# Income                       0
# Education_Level           2622
# Travel_Frequency             0
# Preferred_Activities         0
# Vacation_Budget              0
# Location                     0
# Proximity_to_Mountains    2622
# Proximity_to_Beaches         0
# Favorite_Season              0
# Pets                         0
# Environmental_Concerns       0
# Preference                   0
# dtype: int64

# %%
from sklearn.impute import SimpleImputer

# %%
imp = SimpleImputer(strategy='mean')
data['Age'] = imp.fit_transform(data[['Age']])
data.sample(20)
# Out:
#              Age      Gender  Income Education_Level  Travel_Frequency  \
# 25509  37.000000      female  107580     high school                 7
# 30525  33.000000        male   51656        bachelor                 0
# 24579  65.000000      female   31609     high school                 7
# 35902  50.000000  non-binary   40138          master                 6
# 21419  34.000000      female   76293       doctorate                 9
# 20654  59.000000        male   82218       doctorate                 5
# 20867  37.000000        male   70630        bachelor                 8
# 45490  37.000000        male   22689        bachelor                 0
# 24201  37.000000        male   30606        bachelor                 6
# 36149  31.000000        male   66917     high school                 7
# 32871  55.000000      female   92226        bachelor                 0
# 13021  43.000000      female   39844          master                 2
# 2291   56.000000  non-binary   86322       doctorate                 8
# 11528  39.000000  non-binary   97768     high school                 3
# 45627  50.000000  non-binary   38491       doctorate                 3
# 3364   42.000000  non-binary   78927       doctorate                 5
# 29413  18.000000        male   71466       doctorate                 2
# 28208  56.000000      female  108153          master                 8
# 48211  43.531822        male   70005        bachelor                 3
# 837    27.000000      female   32044          master                 3
#
#       Preferred_Activities  Vacation_Budget  Location  Proximity_to_Mountains  \
# 25509           sunbathing             4272  suburban                    21.0
# 30525               skiing             3827     urban                     5.0
# 24579               skiing             2168  suburban                    51.0
# 35902               hiking             3459     rural                   149.0
# 21419               skiing             3868     urban                    78.0
# 20654           sunbathing             4359     rural                    48.0
# 20867               skiing             2865     rural                    94.0
# 45490             swimming              583  suburban                   114.0
# 24201               skiing             2465     rural                   287.0
# 36149               skiing             2817     urban                   143.0
# 32871               hiking             1426     rural                   114.0
# 13021               skiing             2814  suburban                   127.0
# 2291                skiing             3231  suburban                   286.0
# 11528           sunbathing             1337     urban                   158.0
# 45627             swimming             3217  suburban                     8.0
# 3364                skiing             4409     urban                   121.0
# 29413           sunbathing             1201  suburban                   263.0
# 28208           sunbathing             2723     rural                   225.0
# 48211             swimming             4199     rural                   104.0
# 837                 hiking             2130     rural                   113.0
#
#        Proximity_to_Beaches Favorite_Season  Pets  Environmental_Concerns  \
# 25509                    98          winter     0                       0
# 30525                   147          winter     1                       0
# 24579                   166          winter     0                       1
# 35902                   113          summer     1                       1
# 21419                   185          summer     1                       0
# 20654                   145            fall     0                       1
# 20867                    83          summer     0                       0
# 45490                   100          summer     1                       1
# 24201                    38          winter     1                       0
# 36149                   178          summer     0                       0
# 32871                   296          winter     0                       0
# 13021                    45          winter     0                       0
# 2291                     77          spring     0                       1
# 11528                   147            fall     1                       1
# 45627                   263          summer     1                       1
# 3364                     10          winter     1                       0
# 29413                   121          winter     0                       1
# 28208                   277          summer     0                       1
# 48211                    91          summer     0                       1
# 837                     153          spring     0                       1
#
#        Preference
# 25509           0
# 30525           1
# 24579           1
# 35902           0
# 21419           1
# 20654           0
# 20867           0
# 45490           0
# 24201           0
# 36149           1
# 32871           1
# 13021           0
# 2291            0
# 11528           0
# 45627           0
# 3364            0
# 29413           0
# 28208           0
# 48211           0
# 837             1

# %%
data.isnull().sum()
# Out:
# Age                          0
# Gender                       0
# Income                       0
# Education_Level           2622
# Travel_Frequency             0
# Preferred_Activities         0
# Vacation_Budget              0
# Location                     0
# Proximity_to_Mountains    2622
# Proximity_to_Beaches         0
# Favorite_Season              0
# Pets                         0
# Environmental_Concerns       0
# Preference                   0
# dtype: int64

# %%
imp = SimpleImputer(strategy='most_frequent')
data['Education_Level'] = imp.fit_transform(data[['Education_Level']]).ravel()
data.isnull().sum()
# Out:
# Age                          0
# Gender                       0
# Income                       0
# Education_Level              0
# Travel_Frequency             0
# Preferred_Activities         0
# Vacation_Budget              0
# Location                     0
# Proximity_to_Mountains    2622
# Proximity_to_Beaches         0
# Favorite_Season              0
# Pets                         0
# Environmental_Concerns       0
# Preference                   0
# dtype: int64

# %%
imp = SimpleImputer(strategy='mean')
data['Proximity_to_Mountains'] = imp.fit_transform(data[['Proximity_to_Mountains']])
data.sample(20)
# Out:
#              Age      Gender  Income Education_Level  Travel_Frequency  \
# 10266  58.000000      female  111589          master                 5
# 1672   43.531822  non-binary   22121       doctorate                 4
# 4584   30.000000  non-binary   63475       doctorate                 7
# 26687  39.000000        male   26241       doctorate                 3
# 33197  61.000000        male   85399       doctorate                 4
# 22601  53.000000      female   55140       doctorate                 2
# 38283  58.000000  non-binary   33624       doctorate                 3
# 10390  29.000000        male   70984        bachelor                 3
# 50763  53.000000  non-binary   98304       doctorate                 1
# 35970  56.000000      female   66558          master                 0
# 43023  63.000000        male   61475       doctorate                 5
# 17904  50.000000      female   27883     high school                 3
# 13110  43.000000  non-binary   29381       doctorate                 1
# 3721   58.000000      female   81724        bachelor                 3
# 25267  44.000000  non-binary   40777        bachelor                 3
# 41391  28.000000      female   48915     high school                 4
# 6144   34.000000  non-binary   39011          master                 5
# 48631  68.000000  non-binary   49411        bachelor                 5
# 29020  36.000000  non-binary  118663        bachelor                 0
# 44164  65.000000      female   62057       doctorate                 1
#
#       Preferred_Activities  Vacation_Budget  Location  Proximity_to_Mountains  \
# 10266               skiing             4913     urban                   118.0
# 1672              swimming             1738     urban                   165.0
# 4584              swimming             2340  suburban                   284.0
# 26687           sunbathing             3160     urban                   250.0
# 33197               hiking             1756  suburban                   219.0
# 22601           sunbathing             2157  suburban                    83.0
# 38283               hiking              585     rural                    93.0
# 10390           sunbathing             2221     rural                   145.0
# 50763               skiing             2867     urban                   270.0
# 35970             swimming              782     rural                    64.0
# 43023               skiing             2163     rural                    59.0
# 17904           sunbathing             2045     urban                   162.0
# 13110           sunbathing             1253  suburban                    30.0
# 3721              swimming             1738     rural                   151.0
# 25267           sunbathing             3850     rural                    55.0
# 41391             swimming             3566     rural                   269.0
# 6144            sunbathing             3200  suburban                   101.0
# 48631           sunbathing             3262     rural                   196.0
# 29020             swimming              768     urban                    11.0
# 44164               hiking             4459     rural                   248.0
#
#        Proximity_to_Beaches Favorite_Season  Pets  Environmental_Concerns  \
# 10266                   170          spring     0                       1
# 1672                     30          summer     1                       0
# 4584                    248          summer     0                       1
# 26687                   297            fall     1                       0
# 33197                   209            fall     0                       0
# 22601                   265            fall     0                       1
# 38283                   110          spring     0                       0
# 10390                    56          winter     1                       0
# 50763                    78          summer     0                       1
# 35970                    73          spring     1                       1
# 43023                    18          summer     0                       1
# 17904                   141          spring     0                       0
# 13110                   133          spring     0                       1
# 3721                     73            fall     0                       1
# 25267                   144          winter     0                       1
# 41391                   251          winter     0                       1
# 6144                    137          summer     0                       1
# 48631                    85            fall     0                       0
# 29020                    98          summer     1                       1
# 44164                     4          winter     1                       0
#
#        Preference
# 10266           1
# 1672            0
# 4584            0
# 26687           0
# 33197           0
# 22601           0
# 38283           1
# 10390           0
# 50763           0
# 35970           0
# 43023           0
# 17904           0
# 13110           0
# 3721            0
# 25267           0
# 41391           0
# 6144            0
# 48631           0
# 29020           0
# 44164           0

# %% [markdown]
# ## Dataset Splitting
# Partition the dataset into training and testing sets with an 80:20 ratio.

# %% [markdown]
# ## Feature Scaling
# Standardize the features appropriately.

# %%
from sklearn.preprocessing import LabelEncoder

# %%
# Write your code here. Add as many boxes as you need.
def label(data,columns):
    encoder = LabelEncoder()
    data_copy = data.copy()
    for c in columns:
        data_copy[c] = encoder.fit_transform(data_copy[[c]].astype(str).values.ravel())
    return data_copy

# %%
data = label(data=data, columns=['Gender','Education_Level','Preferred_Activities','Location','Favorite_Season'])
data.sample(20)
# Out:
#              Age  Gender  Income  Education_Level  Travel_Frequency  \
# 23956  30.000000       0   83367                1                 0
# 6164   48.000000       2   60622                1                 5
# 23885  46.000000       1  105658                3                 0
# 22244  43.531822       2  105893                3                 7
# 21892  51.000000       2   95289                1                 6
# 49022  47.000000       1   87806                3                 2
# 50758  32.000000       0  118958                3                 8
# 19133  44.000000       2   76399                1                 7
# 4369   45.000000       0   79977                3                 2
# 17648  36.000000       2   47585                1                 7
# 36500  64.000000       2   53235                2                 9
# 15238  47.000000       2  115753                0                 6
# 18911  67.000000       0  114696                0                 6
# 21384  20.000000       2   30357                3                 5
# 33203  41.000000       0  111729                1                 6
# 42663  44.000000       0   89665                0                 9
# 12432  43.531822       0  100397                2                 3
# 4308   62.000000       1  106583                0                 0
# 1802   43.531822       2   56435                1                 6
# 23096  27.000000       1   30016                0                 0
#
#        Preferred_Activities  Vacation_Budget  Location  \
# 23956                     0              954         0
# 6164                      0             3584         1
# 23885                     2             1512         0
# 22244                     0             4614         1
# 21892                     3             1064         1
# 49022                     2             4115         1
# 50758                     2              800         2
# 19133                     1             2119         2
# 4369                      2             1520         0
# 17648                     0             4760         2
# 36500                     2             4015         1
# 15238                     2             3838         0
# 18911                     2             1852         0
# 21384                     3             3819         2
# 33203                     0             3359         1
# 42663                     3             4817         2
# 12432                     3             2502         0
# 4308                      3             1298         0
# 1802                      1              663         1
# 23096                     2             4260         1
#
#        Proximity_to_Mountains  Proximity_to_Beaches  Favorite_Season  Pets  \
# 23956              204.000000                    70                3     1
# 6164               238.000000                   136                1     1
# 23885              219.000000                   127                3     0
# 22244               98.000000                   237                3     1
# 21892              256.000000                   261                2     1
# 49022              100.000000                   272                3     0
# 50758              149.875878                    97                0     1
# 19133              188.000000                   283                2     0
# 4369               216.000000                   213                3     1
# 17648              100.000000                    26                2     1
# 36500              260.000000                   224                0     1
# 15238                3.000000                   215                0     0
# 18911              120.000000                   206                2     0
# 21384              243.000000                   102                1     1
# 33203              261.000000                   180                1     0
# 42663              125.000000                   102                0     1
# 12432              167.000000                    42                3     1
# 4308               172.000000                   234                0     0
# 1802                25.000000                    59                0     1
# 23096              227.000000                   239                0     0
#
#        Environmental_Concerns  Preference
# 23956                       1           0
# 6164                        1           0
# 23885                       0           0
# 22244                       0           1
# 21892                       1           0
# 49022                       1           0
# 50758                       0           0
# 19133                       1           1
# 4369                        0           0
# 17648                       1           0
# 36500                       1           0
# 15238                       1           0
# 18911                       0           0
# 21384                       1           0
# 33203                       1           0
# 42663                       0           0
# 12432                       0           0
# 4308                        1           0
# 1802                        0           1
# 23096                       1           0

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(data.iloc[:,:-1], data.iloc[:,-1], test_size=0.2)

# %% [markdown]
# ## Model Selection

# %% [markdown]
# Choose and train an approriate model for the given task.

# %%
# Write your code here. Add as many boxes as you need.
from xgboost import XGBClassifier

# %%
model = XGBClassifier(max_depth=50, min_child_weight=1,  n_estimators=200,n_jobs=-1 , verbose=1,learning_rate=0.16)

# %% [markdown]
# Use the trained model to make predictions for the test set.

# %%
# Write your code here. Add as many boxes as you need.
model.fit(X_train,Y_train)
y_pred = model.predict(X_test)
# Out:
# C:\Users\kolov\anaconda3\Lib\site-packages\xgboost\core.py:158: UserWarning: [16:08:21] WARNING: C:\buildkite-agent\builds\buildkite-windows-cpu-autoscaling-group-i-0c55ff5f71b100e98-1\xgboost\xgboost-ci-windows\src\learner.cc:740:
# Parameters: { "verbose" } are not used.
#
#   warnings.warn(smsg, UserWarning)

# %% [markdown]
# Assess the performance of the model by using different classification metrics.

# %%
# Write your code here. Add as many boxes as you need.
from sklearn.metrics import classification_report, confusion_matrix

# %%
print(classification_report(Y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      7935
#            1       0.98      0.97      0.98      2554
#
#     accuracy                           0.99     10489
#    macro avg       0.99      0.98      0.98     10489
# weighted avg       0.99      0.99      0.99     10489

# %% [markdown]
# # Laboratory Exercise - Bonus Task (+ 2 points)

# %% [markdown]
# As part of the bonus task in this laboratory assignment, your objective is to fine-tune at least one hyper-parameter using a cross-validation with grid search. This involves systematically experimenting with various values for the hyper-parameter(s) and evaluating the model's performance using cross-validation. Upon determining the most suitable value(s) for the hyper-parameter(s), evaluate the model's performance on a test set for final assessment.
#
# Hint: Use the `GridCVSearch` from the `scikit-learn` library. Check the documentation at https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.GridSearchCV.html.

# %% [markdown]
# ## Dataset Splitting
# Partition the dataset into training and testing sets with an 90:10 ratio.

# %%
# Write your code here. Add as many boxes as you need.

# %% [markdown]
# ## Feature Scaling
# Standardize the features appropriately.

# %%
# Write your code here. Add as many boxes as you need.

# %% [markdown]
# ## Fine-tuning the Hyperparameters
# Experiment with various values for the chosen hyperparameter(s) and evaluate the model's performance using cross-validation.

# %%
# Write your code here. Add as many boxes as you need.

# %% [markdown]
# ## Final Assessment of the Model Performance
# Upon determining the most suitable hyperparameter(s), evaluate the model's performance on a test set for final assessment.

# %%
# Write your code here. Add as many boxes as you need.
